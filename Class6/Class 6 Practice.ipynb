# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('/Users/devonbancroft/Desktop/Devon-GA-DAT-10-14/data/merge1.xlsx')
df2 = pd.read_excel('/Users/devonbancroft/Desktop/Devon-GA-DAT-10-14/data/merge2.xlsx')

# %%
df1
# Out:
#    ID   Name  Age
# 0   1   Jill   23
# 1   2   Jack   45
# 2   3    Jim   21
# 3   4  Janet   47
# 4   5    Joe   87
# 5   6   Jane   21
# 6   7   Jobe   46
# 7   8  Josie   43
# 8   9   Jean   54
# 9  10   Jess   34

# %%
df2
# Out:
#    ID     Name  Gender
# 0   1     Jill  Female
# 1   2     Jack    Male
# 2   3      Jim    Male
# 3   4    Janet  Female
# 4   6     Jane  Female
# 5   7     Jobe    Male
# 6   8    Josie  Female
# 7   9     Jean    Male
# 8  11    Jacob    Male
# 9  12  Jasmine  Female

# %%
pd.merge(df1, df2, on=['ID','Name'], how='right')
# Out:
#    ID     Name   Age  Gender
# 0   1     Jill  23.0  Female
# 1   2     Jack  45.0    Male
# 2   3      Jim  21.0    Male
# 3   4    Janet  47.0  Female
# 4   6     Jane  21.0  Female
# 5   7     Jobe  46.0    Male
# 6   8    Josie  43.0  Female
# 7   9     Jean  54.0    Male
# 8  11    Jacob   NaN    Male
# 9  12  Jasmine   NaN  Female

# %%
pd.merge(df1, df2, on=['ID','Name'], how='left')
# Out:
#    ID   Name  Age  Gender
# 0   1   Jill   23  Female
# 1   2   Jack   45    Male
# 2   3    Jim   21    Male
# 3   4  Janet   47  Female
# 4   5    Joe   87     NaN
# 5   6   Jane   21  Female
# 6   7   Jobe   46    Male
# 7   8  Josie   43  Female
# 8   9   Jean   54    Male
# 9  10   Jess   34     NaN

# %%
pd.concat([df1,df2])
# Out:
# /Users/devonbancroft/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#     Age  Gender  ID     Name
# 0  23.0     NaN   1     Jill
# 1  45.0     NaN   2     Jack
# 2  21.0     NaN   3      Jim
# 3  47.0     NaN   4    Janet
# 4  87.0     NaN   5      Joe
# 5  21.0     NaN   6     Jane
# 6  46.0     NaN   7     Jobe
# 7  43.0     NaN   8    Josie
# 8  54.0     NaN   9     Jean
# 9  34.0     NaN  10     Jess
# 0   NaN  Female   1     Jill
# 1   NaN    Male   2     Jack
# 2   NaN    Male   3      Jim
# 3   NaN  Female   4    Janet
# 4   NaN  Female   6     Jane
# 5   NaN    Male   7     Jobe
# 6   NaN  Female   8    Josie
# 7   NaN    Male   9     Jean
# ...

# %%
df = pd.read_csv('/Users/devonbancroft/Desktop/Devon-GA-DAT-10-14/data/titanic.csv')

# %%
df.head(1)
# Out:
#    PassengerId  Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1         0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
df1 = df[df.Sex == 'female']

# %%
df1['Survived'] = 12
# Out:
# /Users/devonbancroft/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df.loc[df.Sex == 'female','Survived'] = 3

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         3       1
# 2            3         3       3
# 3            4         3       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df2 = df[df.Sex == 'male'].copy()

# %%
df2.Survived = 3

# %%
df2.head()
# Out:
#    PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0            1         3       3         Braund, Mr. Owen Harris  male  22.0
# 4            5         3       3        Allen, Mr. William Henry  male  35.0
# 5            6         3       3                Moran, Mr. James  male   NaN
# 6            7         3       1         McCarthy, Mr. Timothy J  male  54.0
# 7            8         3       3  Palsson, Master. Gosta Leonard  male   2.0
#
#    SibSp  Parch     Ticket     Fare Cabin Embarked
# 0      1      0  A/5 21171   7.2500   NaN        S
# 4      0      0     373450   8.0500   NaN        S
# 5      0      0     330877   8.4583   NaN        Q
# 6      0      0      17463  51.8625   E46        S
# 7      3      1     349909  21.0750   NaN        S

# %%
df = pd.read_csv('/Users/devonbancroft/Desktop/Devon-GA-DAT-10-14/data/titanic.csv')

# %%
df.isnull().sum() > 0
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.loc[:,df.isnull().sum() > 0]
# Out:
#       Age        Cabin Embarked
# 0    22.0          NaN        S
# 1    38.0          C85        C
# 2    26.0          NaN        S
# 3    35.0         C123        S
# 4    35.0          NaN        S
# 5     NaN          NaN        Q
# 6    54.0          E46        S
# 7     2.0          NaN        S
# 8    27.0          NaN        S
# 9    14.0          NaN        C
# 10    4.0           G6        S
# 11   58.0         C103        S
# 12   20.0          NaN        S
# 13   39.0          NaN        S
# 14   14.0          NaN        S
# 15   55.0          NaN        S
# 16    2.0          NaN        Q
# 17    NaN          NaN        S
# 18   31.0          NaN        S
# 19    NaN          NaN        C
# 20   35.0          NaN        S
# 21   34.0          D56        S
# 22   15.0          NaN        Q
# 23   28.0           A6        S
# 24    8.0          NaN        S
# 25   38.0          NaN        S
# 26    NaN          NaN        C
# 27   19.0  C23 C25 C27        S
# ...

# %%
num_cols = df.select_dtypes(include=np.number).columns.tolist()

# %%
df[num_cols].isnull().sum() > 0
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Age             True
# SibSp          False
# Parch          False
# Fare           False
# dtype: bool

# %%
df[num_cols].mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
df.loc[:,df.isnull().sum() > 0]
# Out:
#            Cabin Embarked
# 0            NaN        S
# 1            C85        C
# 2            NaN        S
# 3           C123        S
# 4            NaN        S
# 5            NaN        Q
# 6            E46        S
# 7            NaN        S
# 8            NaN        S
# 9            NaN        C
# 10            G6        S
# 11          C103        S
# 12           NaN        S
# 13           NaN        S
# 14           NaN        S
# 15           NaN        S
# 16           NaN        Q
# 17           NaN        S
# 18           NaN        S
# 19           NaN        C
# 20           NaN        S
# 21           D56        S
# 22           NaN        Q
# 23            A6        S
# 24           NaN        S
# 25           NaN        S
# 26           NaN        C
# 27   C23 C25 C27        S
# 28           NaN        Q
# 29           NaN        S
# ..           ...      ...
# 861          NaN        S
# 862          D17        S
# 863          NaN        S
# ...

# %%
df[df.duplicated() == False]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
